# %%
import pandas as pd
import numpy as np
import math
df = pd.read_excel('money.xlsx',index_col=None)
newdf = df.to_numpy()

summaryFlag = False
topN = 0
while(1):
    flaginput = input('Do you want txns summary ? (y/n)\n')
    if(flaginput=='y' or flaginput=='Y'):
        summaryFlag = True
        while(1):
            tempN = input('How many top txns do you want to see ? \n')
            if(tempN.isnumeric()):
                topN = int(tempN)
                break
            else:
                print('Enter valid numeric value... \n')
        break
    elif(flaginput=='n' or flaginput=='N'):
        summaryFlag = False
        break
    else:
        print("Enter valid input y/Y/n/N \n")


startyear = 2023
monthsData = ["September", "October", "November", "December", "January", "February", "March", "April", "May", "June", "July", "August"]
monthno = 0

dict = {}

scTotal = 0
hdfcregGTotal = 0
amzniciciTotal = 0
amznPL = 0
flkrtPL = 0
print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
for col in range(0,newdf.shape[1],2):
    print("Month : "+str(col))
    currmonth = monthsData[monthno%12]
    if(currmonth=="January"):
        startyear+=1
    print(str(currmonth)+" "+str(startyear))
    print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
    sctemp = 0
    reggtemp = 0
    amzntemp = 0
    amznPLtemp = 0
    flkrtPLtemp = 0
    for row in range(newdf.shape[0]):
        if(pd.isnull(newdf[row][col])==False):
            if(newdf[row][col].startswith("AmznCC")):
                if(summaryFlag==True):
                    if newdf[row][col] in dict.keys():
                        dict[newdf[row][col]]+=newdf[row][col+1]
                    else:
                        dict[newdf[row][col]] = 0
                        dict[newdf[row][col]]+=newdf[row][col+1]
                    print(newdf[row][col])
                    print(newdf[row][col+1])
                amzntemp+=newdf[row][col+1]
            if(newdf[row][col].startswith("StanCharCC")):
                if(summaryFlag==True):
                    if newdf[row][col] in dict.keys():
                        dict[newdf[row][col]]+=newdf[row][col+1]
                    else:
                        dict[newdf[row][col]] = 0
                        dict[newdf[row][col]]+=newdf[row][col+1]
                    print(newdf[row][col])
                    print(newdf[row][col+1])
                sctemp+=newdf[row][col+1]
            if(newdf[row][col].startswith("REGALIAgold")):
                if(summaryFlag==True):
                    if newdf[row][col] in dict.keys():
                        dict[newdf[row][col]]+=newdf[row][col+1]
                    else:
                        dict[newdf[row][col]] = 0
                        dict[newdf[row][col]]+=newdf[row][col+1]
                    print(newdf[row][col])
                    print(newdf[row][col+1])
                reggtemp+=newdf[row][col+1]
            if(col<8 and newdf[row][col].startswith("AmznPL")):
                if(summaryFlag==True):
                    if newdf[row][col] in dict.keys():
                        dict[newdf[row][col]]+=newdf[row][col+1]
                    else:
                        dict[newdf[row][col]] = 0
                        dict[newdf[row][col]]+=newdf[row][col+1]
                    print(newdf[row][col])
                    print(newdf[row][col+1])
                amznPLtemp+=newdf[row][col+1]
            if(col<8 and newdf[row][col].startswith("FlkrtPL")):
                if(summaryFlag==True):
                    if newdf[row][col] in dict.keys():
                        dict[newdf[row][col]]+=newdf[row][col+1]
                    else:
                        dict[newdf[row][col]] = 0
                        dict[newdf[row][col]]+=newdf[row][col+1]
                    print(newdf[row][col])
                    print(newdf[row][col+1])
                flkrtPLtemp+=newdf[row][col+1]

    scTotal+=sctemp
    hdfcregGTotal+=reggtemp
    amzniciciTotal+=amzntemp
    amznPL+=amznPLtemp
    flkrtPL+=flkrtPLtemp
    print("                                ")
    print("                                ")
    print("approximate figures...")
    print("Standard Chartered Ultimate in month "+currmonth+" "+str(startyear)+" : "+str(sctemp))
    print("HDFC Regalia Gold in month "+currmonth+" "+str(startyear)+" : "+str(reggtemp))
    print("AmazonPay icici in month "+currmonth+" "+str(startyear)+" : "+str(amzntemp))
    if(col==8):
        print("Amazon PayLater & Flipkart PayLater are closed after this month")
    if(col<8):
        print("Amazon PayLater in month "+currmonth+" "+str(startyear)+" : "+str(amznPLtemp))
        print("Flipkart PayLater in month "+currmonth+" "+str(startyear)+" : "+str(flkrtPLtemp))
    print("                                                         ")
    print("-> Total spent on Credit Cards in month "+currmonth+" "+str(startyear)+" : "+str(sctemp+reggtemp+amzntemp+amznPLtemp+flkrtPLtemp))
    print("                                ")
    print("                                ")
        
    monthno+=1
    print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")



print("                                ")
print("                                ")
print("TOTAL:")
print("approximate figures...")
print("Standard Chartered Ultimate Total: "+str(scTotal))
print("HDFC Regalia Gold Total: "+str(hdfcregGTotal))
print("AmazonPay icici Total: "+str(amzniciciTotal))
print("Amazon PayLater Total: "+str(amznPL))
print("Flipkart PayLater Total: "+str(flkrtPL))
print("                                                                ")
print("--> Total spent on Credit Cards: "+str(scTotal+hdfcregGTotal+amzniciciTotal+amznPL+flkrtPL))

print("                                ")
print("                                ")

if(summaryFlag==True):
    print("Showing top "+str(topN)+" txns from data....")
    sorteddict = sorted(dict.items(), reverse=True,key=lambda item: float(item[1]))
    for dataline in sorteddict:
        if(topN==0):
            break
        print(str(dataline[0]) + " : "+str(dataline[1]))
        topN-=1
# Out:
# Do you want txns summary ? (y/n)
#  y
# How many top txns do you want to see ?
#  2
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Month : 0
# September 2023
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# AmznPL Samsung Buds2
# 6098.0
# FlkrtPL trollybag
# 1526.0
# FlkrtPL matress
# 1872.0
# AmznCC urbanladder queenBed
# 1175.0
# AmznCC wonderchef SmartPot
# 1067.0
# AmznCC whirlpool washer
# 1050.0
# AmznCC Sleepycat pillow&bedding combo
# 1160.0
# AmznCC Sleepycat luxe duvet cotton
# 1200.0
# AmznCC dmart Bengaluru
# 3000.0
# AmznCC Decathlon waistbag
# 600.0
# AmznCC flipkart carpet
# 350.0
# AmznCC moviesnacks
# 250.0
# AmznCC Giva Earrings
# 1349.0
#
#
# approximate figures...
# Standard Chartered Ultimate in month September 2023 : 0
# HDFC Regalia Gold in month September 2023 : 0
# AmazonPay icici in month September 2023 : 11201.0
# Amazon PayLater in month September 2023 : 6098.0
# Flipkart PayLater in month September 2023 : 3398.0
#
# -> Total spent on Credit Cards in month September 2023 : 20697.0
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Month : 2
# October 2023
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# AmznCC Levi's pheoix jeans and polo
# 6150.0
# AmznCC OvenGloves & flipflops
# 533.0
# FlkrtPL matress
# 1872.0
# AmznCC urbanladder queenBed
# 1175.0
# AmznCC wonderchef SmartPot
# 1067.0
# AmznCC whirlpool washer
# 1050.0
# AmznCC Sleepycat pillow&bedding combo
# 1160.0
# AmznCC Sleepycat luxe duvet cotton
# 1200.0
# AmznCC aaiBusIndore
# 1995.0
# AmznCC trainBLR-LUR-BLR
# 3500.0
# AmznCC HouseOfCommons Party Sunday
# 955.0
# AmznCC punjabiRasoi & balconyBar (588+249)
# 837.0
# AmznCC SamsungGalaxyPhone  aai
# 14039.0
#
#
# approximate figures...
# Standard Chartered Ultimate in month October 2023 : 0
# HDFC Regalia Gold in month October 2023 : 0
# AmazonPay icici in month October 2023 : 33661.0
# Amazon PayLater in month October 2023 : 0
# Flipkart PayLater in month October 2023 : 1872.0
#
# -> Total spent on Credit Cards in month October 2023 : 35533.0
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Month : 4
# November 2023
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# StanCharCC Louis Philippe wallet
# 2249.0
# AmznCC Bitdefender PC internet security
# 599.0
# FlkrtPL matress
# 1872.0
# AmznCC urbanladder queenBed
# 1175.0
# AmznCC wonderchef SmartPot
# 1067.0
# AmznCC whirlpool washer
# 1050.0
# AmznCC Sleepycat pillow&bedding combo
# 1160.0
# AmznCC Sleepycat luxe duvet cotton
# 1200.0
# StanCharCC Centro mall Benetton shoes 5k & indian terrain pant
# 5748.0
# StanCharCC PVR caramal popcorn and coke in MissionImpossible 7 Rewatch
# 490.0
# AmznCC pvr mission impossible 7
# 346.0
# AmznCC baba's Levis jeans and arrows shirt blue and white
# 3085.0
# AmznCC amazonSolimo Premium : shirts pack of two & one black shirt
# 2805.0
# AmznCC mini's Boat soundbar
# 1299.0
# AmznCC AmazonBasics keyboardMouseWireless Combo
# 899.0
# AmznCC Electricity Bill IndiranagarHome
# 2084.0
# AmznCC Paris Panini Indiranagar 10" with watermelon juice
# 609.0
# AmznCC Netflix subscription premium & Microsoft PC HEVC codec install
# 703.0
# AmznCC philips extension with control switchs
# 569.0
# AmznCC fire TV stick 4k
# 3199.0
#
#
# approximate figures...
# Standard Chartered Ultimate in month November 2023 : 8487.0
# HDFC Regalia Gold in month November 2023 : 0
# AmazonPay icici in month November 2023 : 21849.0
# Amazon PayLater in month November 2023 : 0
# Flipkart PayLater in month November 2023 : 1872.0
#
# -> Total spent on Credit Cards in month November 2023 : 32208.0
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Month : 6
# December 2023
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# AmznCC Lur to Blr train tkt irctc
# 1256.0
# StanCharCC MG Road 1522 bar screwdriver cocktail & budwiser magnum & peri peri fries
# 862.0
# StanCharCC BurgerKing Indiranagar
# 293.0
# AmznCC urbanladder queenBed
# 1175.0
# AmznCC wonderchef SmartPot
# 1067.0
# AmznCC whirlpool washer
# 1050.0
# REGALIAgold Samsung galaxy zfip5
# 9937.0
# REGALIAgold pheonix whitefield tiger thai pepper grill fish meal
# 468.0
# REGALIAgold Interstellar movie
# 283.0
# REGALIAgold orion mall burger king 200 chocolate shake and pvr popcorn 515
# 715.0
# REGALIAgold Reliance fresh packaged juices
# 262.0
# AmznCC Samsung Superfast charger and 10kW power bank
# 2448.0
# AmznCC amazonPrime yearly 1499 subscription autopay
# 1499.0
# AmznCC borosil 6glass set for me 495 and electric water dispenser for latur home 399
# 894.0
# REGALIAgold mkretail supermarket indiranagar
# 1019.0
# AmznCC Baba's Diwali party shopping cloths already paid back
# 7773.0
# AmznCC movie Tiger 3 ticket
# 413.0
# AmznCC Netflix monthly 4kUHD plan
# 649.0
# StanCharCC Mcdonalds indiranagar meal
# 304.0
# AmznCC GooglePlay recharge for googleOne storage and Youtube subscription
# 1000.0
# AmznCC curtain for window
# 199.0
# AmznCC luxCozi baniyan x6
# 487.0
#
#
# approximate figures...
# Standard Chartered Ultimate in month December 2023 : 1459.0
# HDFC Regalia Gold in month December 2023 : 12684.0
# AmazonPay icici in month December 2023 : 19910.0
# Amazon PayLater in month December 2023 : 0
# Flipkart PayLater in month December 2023 : 0
#
# -> Total spent on Credit Cards in month December 2023 : 34053.0
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Month : 8
# January 2024
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# StanCharCC Marks&Spencer black formal shoes and pants
# 2900
# StanCharCC Louis Philippe black formal belt
# 1399
# StanCharCC Mcdonalds indiranagar meal
# 270
# AmznCC urbanladder queenBed
# 1175
# AmznCC wonderchef SmartPot
# 1067
# AmznCC whirlpool washer
# 1050
# REGALIAgold Samsung galaxy zfip5
# 9937
# StanCharCC indiranagar supermarket MKRetail
# 912
# StanCharCC mandir devghar woodenstreet aai birthday gift
# 4900
# StanCharCC hanuman ji idol
# 3324
# REGALIAgold Toni&Guy Indiranagar haircut, black colour and wella sp scalp moisturizer
# 3872
# StanCharCC MKretail supermarket pasta ramen etc grocery
# 679
# StanCharCC mcdonalds indiranagar meal
# 360
# StanCharCC the souled store 2 beach shorts and 2 black tshirt for trip
# 2516
# REGALIAgold meghana biryani
# 420
# AmznCC movie Animal ticket inox mantri square IMAX: used 400 Rs amazon card cashback
# 273
# AmznCC prestige induction and pan combo, roti mat and latana & bucket set
# 3867
# AmznCC Bolosil Larah dinnerset 19pcs
# 1263
# AmznCC TSAlock for bagpack
# 465
# REGALIAgold pvrInox animal movie salted and caramel popcorn and bisleri
# 600
# REGALIAgold pizzahut indiranagar adjusted amount
# 743
# REGALIAgold Mini's gift tote bag myntra
# 2399
# StanCharCC vistara flight BLR-GOA 8thDEC2023
# 3900
# AmznCC vistara flight GOA-BLR 12thDEC2023
# 3060
# StanCharCC Mcdonald meal indiranagar
# 313
# StanCharCC MKRetail supermarket cookies, kitchensupplies, allout, etc
# 1580
# AmznCC solimo doublebed Comforter - used amazonpaybalance also
# 929
# StanCharCC manyavar indiranagar kurta jacket full piece set
# 10298
# StanCharCC theobrama indiranagar pastries with mini and aai
# 578
# StanCharCC BLR airport Johnny rocket burger route66 veg
# 492
# AmznCC dinner set rack
# 463
# AmznCC movie sambahadur with aai and mini
# 763
# StanCharCC MKRetail supermarket kitchen hardware supplies, veggies and extras
# 1650
# StanCharCC PVR Orion mall sambahadur movie popcorn large
# 470
# REGALIAgold goa adlem goa lunch/ meal, fish dishes and etc contri done
# 2399
# REGALIAgold Tomatos goa party bill contri done
# 10067
# REGALIAgold entry fees for dudhsagar contri done
# 500
# REGALIAgold colourful street hospedaria venite goa
# 274
# AmznCC Netflix monthly 4kUHD plan
# 649
# StanCharCC MKRetail indiranagar Kitchen supplies and tools with aai
# 1650
# StanCharCC Nagarjuna indiranagar with aai and mini
# 1290
# StanCharCC AshaSweets Indiranage for aai and Home
# 900
# StanCharCC MKRetail indiranagar kitchen supplies and veggies
# 800
# StanCharCC TheArtarium RAM MANDIR
# 2000
# AmznCC MickyMouse Hoodie 620 and aquaman 2 4dx 3d pvr orion mall blr ticket 920
# 1540
#
#
# approximate figures...
# Standard Chartered Ultimate in month January 2024 : 43181
# HDFC Regalia Gold in month January 2024 : 31211
# AmazonPay icici in month January 2024 : 16564
# Amazon PayLater & Flipkart PayLater are closed after this month
#
# -> Total spent on Credit Cards in month January 2024 : 90956
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Month : 10
# February 2024
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# REGALIAgold taiki indiranagar fnb pwans kimchi rice and spicy guava mocktail
# 870.0
# REGALIAgold titanEye+ indiranagar sunglasses and specs new both powered and drive easy lens
# 12399.0
# StanCharCC pvr aquaman 2 pvr 4dx orion mall blr  popcorn and popcorn shake(bad)
# 835.0
# AmznCC urbanladder queenBed
# 1175.0
# AmznCC wonderchef SmartPot
# 1067.0
# AmznCC whirlpool washer
# 1050.0
# REGALIAgold Samsung galaxy zfip5
# 9937.0
# REGALIAgold jackson js11 dinky metallic blue
# 6000.0
# REGALIAgold Yamaha GA15II amplifier
# 2500.0
# StanCharCC maravanthe coastal indiranagar fishcurry and rice
# 800.0
# StanCharCC Mcdonalds indiranagar meal
# 288.0
# StanCharCC Mcdonalds indiranagar meal
# 343.0
# StanCharCC new year's eve house party at whitefield friends home booze brocode, budweiser magnum and oldmonk
# 630.0
# AmznCC Books statquest machine learning 402(removing amznpaybalance) & why bharat matters s jaishankar 560
# 960.0
# StanCharCC mkretail grocery indiranagar store sandwitch supplies and veggies
# 930.0
# REGALIAgold nbc store THE BLACKLIST merch rock glass with logo import $50.91
# 4300.0
# REGALIAgold spotify 12 months discounted
# 1189.0
# AmznCC electricity bill DEC-JAN bescom
# 2014.0
# StanCharCC mkretail grocery indiranagar store 2 times (1000) +(850)
# 1850.0
# AmznCC amazonBasics beach type recliner for terrace and home
# 3599.0
# REGALIAgold myntra grey formalPant louisPhillipe & black polo arrows  total-(hdfcCard 1500 coupen used)
# 969.0
# AmznCC Netflix monthly 4kUHD plan
# 649.0
# AmznCC ExGuitar cable fender delux, picks and guitar stand
# 3000.0
#
#
# approximate figures...
# Standard Chartered Ultimate in month February 2024 : 5676.0
# HDFC Regalia Gold in month February 2024 : 38164.0
# AmazonPay icici in month February 2024 : 13514.0
#
# -> Total spent on Credit Cards in month February 2024 : 57354.0
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Month : 12
# March 2024
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# StanCharCC  jioFiber 150mbps plan x3 months (reimbursement from oracle)
# 3500.0
# StanCharCC Souled Store striped sweatshirt
# 1400.0
# StanCharCC Adultees absolute vodka santra whote tshirt
# 699.0
# StanCharCC urbanmonkey black with logo and clear white tshirt
# 2042.0
# StanCharCC mcdonald indiranagar meal
# 363.0
# AmznCC whirlpool washer
# 1050.0
# REGALIAgold Samsung galaxy zfip5
# 9937.0
# REGALIAgold jackson js11 dinky metallic blue
# 6000.0
# REGALIAgold Yamaha GA15II amplifier
# 2500.0
# REGALIAgold airIndia BLR->Ahmdbad 9th feb
# 5120.0
# REGALIAgold vistara ahmdbad->BLR 13th Feb
# 6300.0
# StanCharCC myntra Levi's leather bomber jacket mrp9000
# 3900.0
# REGALIAgold nh8 indiranagar blr rajasthani thali full meal with ishan, rishabh split done
# 1762.0
# REGALIAgold mcdonalds indiranagar mc maharaja burger
# 219.0
# REGALIAgold TBC sky lounge blr with ishan rishabh split done
# 2226.0
# REGALIAgold sukh sagar majestic blr hotel food with ishan rishabh split done
# 750.0
# REGALIAgold truffles indiranagar burger and desserts with ishan and devana
# 1155.0
# StanCharCC wellbi page instagram ad 2 shirts good
# 1670.0
# AmznCC havells hair dryer
# 989.0
# StanCharCC mkretail indiranagar grocery ,nutella , soap , veggies , munchies,etc and Mcdonald meal 326
# 1560.0
# AmznCC amazonbasics toaster 1999 used CC rewards
# 1751.0
# REGALIAgold google one 200GB subscription
# 210.0
# AmznCC electricity bill indiranagar house
# 1860.0
# AmznCC Netflix monthly 4kUHD plan
# 649.0
# REGALIAgold mcdonald meal on gujarat trip night
# 290.0
# REGALIAgold gujarat highway jadeja's motel hocco's chole thalix3 and  sundae x3
# 1400.0
#
#
# approximate figures...
# Standard Chartered Ultimate in month March 2024 : 15134.0
# HDFC Regalia Gold in month March 2024 : 37869.0
# AmazonPay icici in month March 2024 : 6299.0
#
# -> Total spent on Credit Cards in month March 2024 : 59302.0
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Month : 14
# April 2024
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# StanCharCC Resanskrit bharat mata painting frame
# 600.0
# AmznCC whirlpool washer
# 1050.0
# REGALIAgold Samsung galaxy zfip5
# 9937.0
# REGALIAgold jackson js11 dinky metallic blue
# 6000.0
# REGALIAgold Yamaha GA15II amplifier
# 2500.0
#
#
# approximate figures...
# Standard Chartered Ultimate in month April 2024 : 600.0
# HDFC Regalia Gold in month April 2024 : 18437.0
# AmazonPay icici in month April 2024 : 1050.0
#
# -> Total spent on Credit Cards in month April 2024 : 20087.0
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Month : 16
# May 2024
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# AmznCC whirlpool washer
# 1050.0
# REGALIAgold Samsung galaxy zfip5
# 9937.0
#
#
# approximate figures...
# Standard Chartered Ultimate in month May 2024 : 0
# HDFC Regalia Gold in month May 2024 : 9937.0
# AmazonPay icici in month May 2024 : 1050.0
#
# -> Total spent on Credit Cards in month May 2024 : 10987.0
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Month : 18
# June 2024
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# AmznCC whirlpool washer
# 1050.0
# REGALIAgold Samsung galaxy zfip5
# 9937.0
#
#
# approximate figures...
# Standard Chartered Ultimate in month June 2024 : 0
# HDFC Regalia Gold in month June 2024 : 9937.0
# AmazonPay icici in month June 2024 : 1050.0
#
# -> Total spent on Credit Cards in month June 2024 : 10987.0
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Month : 20
# July 2024
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# AmznCC whirlpool washer
# 1050.0
# REGALIAgold Samsung galaxy zfip5
# 9937.0
#
#
# approximate figures...
# Standard Chartered Ultimate in month July 2024 : 0
# HDFC Regalia Gold in month July 2024 : 9937.0
# AmazonPay icici in month July 2024 : 1050.0
#
# -> Total spent on Credit Cards in month July 2024 : 10987.0
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Month : 22
# August 2024
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# AmznCC whirlpool washer
# 1050.0
# REGALIAgold Samsung galaxy zfip5
# 9937.0
#
#
# approximate figures...
# Standard Chartered Ultimate in month August 2024 : 0
# HDFC Regalia Gold in month August 2024 : 9937.0
# AmazonPay icici in month August 2024 : 1050.0
#
# -> Total spent on Credit Cards in month August 2024 : 10987.0
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# TOTAL:
# approximate figures...
# Standard Chartered Ultimate Total: 74537.0
# HDFC Regalia Gold Total: 178113.0
# AmazonPay icici Total: 128248.0
# Amazon PayLater Total: 6098.0
# Flipkart PayLater Total: 7142.0
#
# --> Total spent on Credit Cards: 394138.0
#
#
# Showing top 2 txns from data....
# REGALIAgold Samsung galaxy zfip5 : 89433.0
# REGALIAgold jackson js11 dinky metallic blue : 18000.0
